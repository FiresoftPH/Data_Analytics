# %%
import pandas as pd

file_name = str(input("Enter your file name here: "))
df = pd.read_excel(file_name)
# Out:
# /var/folders/99/5xpfg5r16zj8_010_0k35yk40000gn/T/ipykernel_3143/3211878502.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df
# Out:
#      date_of_submission species  submitted_sample vitek_id  bacteria_genus  \
# 0            2017-02-24     dog         ub mucosa       GP  staphylococcus
# 1            2019-01-11     dog        bite wound       GP  staphylococcus
# 2            2016-07-08     dog             urine       GP  staphylococcus
# 3            2016-07-08     cat             urine       GP  staphylococcus
# 4            2016-07-08     dog               pus       GP  staphylococcus
# ...                 ...     ...               ...      ...             ...
# 3380         2019-12-19     dog      opened wound       GP  staphylococcus
# 3381         2019-12-11     dog  abdominal cavity       GP  staphylococcus
# 3382         2019-12-02     dog           unknown       GP  staphylococcus
# 3383         2019-12-09     cat             urine       GP  staphylococcus
# 3384         2019-12-13     cat             urine       GP    enterococcus
#
# ...

# %%
# Fill NA with U
df = df.fillna("U")

# %%
df
# Out:
#      date_of_submission species  submitted_sample vitek_id  bacteria_genus  \
# 0            2017-02-24     dog         ub mucosa       GP  staphylococcus
# 1            2019-01-11     dog        bite wound       GP  staphylococcus
# 2            2016-07-08     dog             urine       GP  staphylococcus
# 3            2016-07-08     cat             urine       GP  staphylococcus
# 4            2016-07-08     dog               pus       GP  staphylococcus
# ...                 ...     ...               ...      ...             ...
# 3380         2019-12-19     dog      opened wound       GP  staphylococcus
# 3381         2019-12-11     dog  abdominal cavity       GP  staphylococcus
# 3382         2019-12-02     dog           unknown       GP  staphylococcus
# 3383         2019-12-09     cat             urine       GP  staphylococcus
# 3384         2019-12-13     cat             urine       GP    enterococcus
#
# ...

# %%
filename = str(input("Enter the name of the file you want to save: "))
df.to_excel("{}.xlsx".format(filename), index=False)
